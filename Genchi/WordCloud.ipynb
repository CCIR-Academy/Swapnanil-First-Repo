# %%
pip install numpy matplotlib pillow wordcloud imageio

# %%
import wordcloud
import matplotlib.pyplot as plt
mask = plt.imread('/theatre-of-ancient-greece-mask-cinema-clip-art-theatre-mask.jpg')

myWordCloud = wordcloud.WordCloud(mask=mask)
wordcloud.random_color_func()
with open('/worddata.txt', encoding='utf-8') as f:
    myWordCloud.generate(f.read())
# myWordCloud.to_file('/myWordCloud.png')
plt.imshow(myWordCloud)
plt.axis('off')
plt.show()

# %%
plt.imshow(mask)
